# %% [markdown]
# **Marketing A/B Testing**

# %% [markdown]
# **About :** It is an Synthetic Dataset of 588101 rows x 7 columns containing the data regarding the company.

# %%
import numpy as np
import matplotlib as plt
import pandas as pd
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv('/content/drive/MyDrive/Marketing A-B Testing/marketing_AB.csv')
display(df.head())
# Out:
#    Unnamed: 0  user id test group  converted  total ads most ads day  \
# 0           0  1069124         ad      False        130       Monday
# 1           1  1119715         ad      False         93      Tuesday
# 2           2  1144181         ad      False         21      Tuesday
# 3           3  1435133         ad      False        355      Tuesday
# 4           4  1015700         ad      False        276       Friday
#
#    most ads hour
# 0             20
# 1             22
# 2             18
# 3             10
# 4             14

# %% [markdown]
# **Basic Understanding regarding the dataset**

# %% [markdown]
# **Display the top 5 rows in the dataset**

# %%
df.head()
# Out:
#    Unnamed: 0  user id test group  converted  total ads most ads day  \
# 0           0  1069124         ad      False        130       Monday
# 1           1  1119715         ad      False         93      Tuesday
# 2           2  1144181         ad      False         21      Tuesday
# 3           3  1435133         ad      False        355      Tuesday
# 4           4  1015700         ad      False        276       Friday
#
#    most ads hour
# 0             20
# 1             22
# 2             18
# 3             10
# 4             14

# %% [markdown]
# **Display the last 5 rows in the dataset**

# %%
df.tail()
# Out:
#         Unnamed: 0  user id test group  converted  total ads most ads day  \
# 588096      588096  1278437         ad      False          1      Tuesday
# 588097      588097  1327975         ad      False          1      Tuesday
# 588098      588098  1038442         ad      False          3      Tuesday
# 588099      588099  1496395         ad      False          1      Tuesday
# 588100      588100  1237779         ad      False          1      Tuesday
#
#         most ads hour
# 588096             23
# 588097             23
# 588098             23
# 588099             23
# 588100             23

# %% [markdown]
# **Read the data from 21 to 30**

# %%
df.head(31).tail(10)
# Out:
#     Unnamed: 0  user id test group  converted  total ads most ads day  \
# 21          21  1478526         ad      False        389     Saturday
# 22          22  1436823         ad      False        136       Sunday
# 23          23  1274572         ad      False         47     Saturday
# 24          24  1441220         ad      False        264     Saturday
# 25          25  1025687         ad      False         87      Tuesday
# 26          26  1451900         ad      False         46      Tuesday
# 27          27  1098821         ad      False          3      Tuesday
# 28          28  1333281         ad      False        114       Monday
# 29          29  1238323         ad      False        175     Thursday
# 30          30  1034350         ad      False         87      Tuesday
#
#     most ads hour
# 21             19
# 22             16
# 23             21
# 24              3
# 25             23
# 26             20
# 27             19
# 28             23
# 29             21
# ...

# %%
help(df.iloc())
# Out:
# Help on _iLocIndexer in module pandas.core.indexing object:
#
# class _iLocIndexer(_LocationIndexer)
#  |  Purely integer-location based indexing for selection by position.
#  |
#  |  .. deprecated:: 2.2.0
#  |
#  |     Returning a tuple from a callable is deprecated.
#  |
#  |  ``.iloc[]`` is primarily integer position based (from ``0`` to
#  |  ``length-1`` of the axis), but may also be used with a boolean
#  |  array.
#  |
#  |  Allowed inputs are:
#  |
#  |  - An integer, e.g. ``5``.
#  |  - A list or array of integers, e.g. ``[4, 3, 0]``.
#  |  - A slice object with ints, e.g. ``1:7``.
#  |  - A boolean array.
#  |  - A ``callable`` function with one argument (the calling Series or
#  |    DataFrame) and that returns valid output for indexing (one of the above).
#  |    This is useful in method chains, when you don't have a reference to the
#  |    calling object, but would like to base your selection on
#  |    some value.
# ...

# %% [markdown]
# **Display first Row**

# %%
df.iloc[[0]]
# Out:
#    Unnamed: 0  user id test group  converted  total ads most ads day  \
# 0           0  1069124         ad      False        130       Monday
#
#    most ads hour
# 0             20

# %% [markdown]
# **Display Rows from 21 to 30**

# %%
df.iloc[21:31]
# Out:
#     Unnamed: 0  user id test group  converted  total ads most ads day  \
# 21          21  1478526         ad      False        389     Saturday
# 22          22  1436823         ad      False        136       Sunday
# 23          23  1274572         ad      False         47     Saturday
# 24          24  1441220         ad      False        264     Saturday
# 25          25  1025687         ad      False         87      Tuesday
# 26          26  1451900         ad      False         46      Tuesday
# 27          27  1098821         ad      False          3      Tuesday
# 28          28  1333281         ad      False        114       Monday
# 29          29  1238323         ad      False        175     Thursday
# 30          30  1034350         ad      False         87      Tuesday
#
#     most ads hour
# 21             19
# 22             16
# 23             21
# 24              3
# 25             23
# 26             20
# 27             19
# 28             23
# 29             21
# ...

# %%
df.iloc[[0,2], [1,2,3,4]]
# Out:
#    user id test group  converted  total ads
# 0  1069124         ad      False        130
# 2  1144181         ad      False         21

# %% [markdown]
# **How many rows and columns are present in this dataset?**

# %%
df.shape
# Out:
# (588101, 7)

# %% [markdown]
# **Find the columns and their datatypes**

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'user id', 'test group', 'converted', 'total ads',
#        'most ads day', 'most ads hour'],
#       dtype='object')

# %% [markdown]
# **Find the data types of the dataset**

# %%
df.dtypes
# Out:
# Unnamed: 0        int64
# user id           int64
# test group       object
# converted          bool
# total ads         int64
# most ads day     object
# most ads hour     int64
# dtype: object

# %% [markdown]
# **Overview of the dataset**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 588101 entries, 0 to 588100
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Unnamed: 0     588101 non-null  int64
#  1   user id        588101 non-null  int64
#  2   test group     588101 non-null  object
#  3   converted      588101 non-null  bool
#  4   total ads      588101 non-null  int64
#  5   most ads day   588101 non-null  object
#  6   most ads hour  588101 non-null  int64
# dtypes: bool(1), int64(4), object(2)
# memory usage: 27.5+ MB

# %% [markdown]
# **Tell me about null values based on each columns**

# %%
df.isnull().sum()
# Out:
# Unnamed: 0       0
# user id          0
# test group       0
# converted        0
# total ads        0
# most ads day     0
# most ads hour    0
# dtype: int64

# %% [markdown]
# **Find the duplicate rows**

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#           Unnamed: 0       user id      total ads  most ads hour
# count  588101.000000  5.881010e+05  588101.000000  588101.000000
# mean   294050.000000  1.310692e+06      24.820876      14.469061
# std    169770.279667  2.022260e+05      43.715181       4.834634
# min         0.000000  9.000000e+05       1.000000       0.000000
# 25%    147025.000000  1.143190e+06       4.000000      11.000000
# 50%    294050.000000  1.313725e+06      13.000000      14.000000
# 75%    441075.000000  1.484088e+06      27.000000      18.000000
# max    588100.000000  1.654483e+06    2065.000000      23.000000

# %% [markdown]
# **Count :** Number of non-null values
#
# **mean :** Avergae value
#
# **std :** Standard deviation (spread of data)
#
# **min :** Smallest Value
#
# **25% :** First Quartile (Q1)
#
# **50% :** Meadian
#
# **75% :** Third Quatile
#
# **max :** Largest Value

# %% [markdown]
# **Data Cleaning - Unnamed**

# %% [markdown]
# **Explanation** : Since that Unnamed column is just giving row numbers, it is completely useless for our analysis

# %%
df = df.drop(columns=['Unnamed: 0'])

# %% [markdown]
# **Verifying the existing columns**

# %%
print(df.columns.tolist())
# Out:
# ['user id', 'test group', 'converted', 'total ads', 'most ads day', 'most ads hour']

# %%
df.describe()
# Out:
#             user id      total ads  most ads hour
# count  5.881010e+05  588101.000000  588101.000000
# mean   1.310692e+06      24.820876      14.469061
# std    2.022260e+05      43.715181       4.834634
# min    9.000000e+05       1.000000       0.000000
# 25%    1.143190e+06       4.000000      11.000000
# 50%    1.313725e+06      13.000000      14.000000
# 75%    1.484088e+06      27.000000      18.000000
# max    1.654483e+06    2065.000000      23.000000

# %% [markdown]
# **Data Cleaning - Userid**

# %% [markdown]
# **Checking the null values in these columns**

# %%
print("user id :", df['user id'].isnull().sum())
# Out:
# user id : 0

# %% [markdown]
# **Checking Unique Values in the User id Column**

# %%
print(df['user id'].unique())
# Out:
# [1069124 1119715 1144181 ... 1038442 1496395 1237779]

# %% [markdown]
# **Find the duplicate rows in these columns**

# %%
print("User ID duplicates:", df['user id'].duplicated().sum())
# Out:
# User ID duplicates: 0

# %% [markdown]
# **Data Cleaning - Test group**

# %% [markdown]
# **Checking the null values in these columns**

# %%
print("test group :", df['test group'].isnull().sum())
# Out:
# test group : 0

# %% [markdown]
# **Checking Unique Values in the test group Column**

# %%
print(df['test group'].unique())
# Out:
# ['ad' 'psa']

# %% [markdown]
# **Data Cleaning - Converted**

# %% [markdown]
# **Checking the null values in these columns**

# %%
print("converted :", df['converted'].isnull().sum())
# Out:
# converted : 0

# %% [markdown]
# **Checking Unique Values in the Converted Column**

# %%
print(df['converted'].unique())
# Out:
# [False  True]

# %% [markdown]
# **Data Cleaning - total ads**

# %% [markdown]
# **Checking the null values in these columns**

# %%
print("total ads :", df['total ads'].isnull().sum())
# Out:
# total ads : 0

# %% [markdown]
# **Checking Unique Values in the total ads Column**

# %%
print(df['total ads'].unique())
# Out:
# [ 130   93   21  355  276  734  264   17  142  209   47   61   40   20
#     9   64   26  248   73  281  389  136   87   46    3  114  175  119
#   313   89  364   24  112   49   27  274   45  177   90  265   71   31
#   588   56  108  103  239   63   66  111   74   14  258 1057  137  131
#   124   13   37  738  199  211   98   19  127   18  126  197   77   60
#    95   97   22  117   41   57  593   28   85   53   43  133   33 1328
#     7    6   62  247  464   99  233  139  407  323   76  395  166   34
#   246  653  122   32  386   44  138  109   39  159   30   59  421  446
#   555  105  128  310  163   10  290  164   79  312   16  161  505  640
#   118  266  456   80  100  983   36    1    5  463  720   52  442  334
#  1056  270  240  194  271  489  115  180  241   15  154  120   29  107
#   176    8  146  121   50   69  297   35   78  170  214   81    2   38
#   681  733   23  157  153  135   88  167    4   58  195  318   48   83
# ...

# %% [markdown]
# **Data Cleaning - most ads day**

# %% [markdown]
# **Checking the null values in these columns**

# %%
print("most ads day :", df['most ads day'].isnull().sum())
# Out:
# most ads day : 0

# %% [markdown]
# **Checking Unique Values in the most ads day Column**

# %%
print(df['most ads day'].unique())
# Out:
# ['Monday' 'Tuesday' 'Friday' 'Saturday' 'Wednesday' 'Sunday' 'Thursday']

# %% [markdown]
# **Data Cleaning - most ads hour**

# %% [markdown]
# **Checking the null values in these columns**

# %%
print("most ads hour :", df['most ads hour'].isnull().sum())
# Out:
# most ads hour : 0

# %% [markdown]
# **Checking Unique Values in the most ads hour Column**

# %%
print(df['most ads hour'].unique())
# Out:
# [20 22 18 10 14 13 19 11 12 16 21  3 23  4  8  0  2 15  1  6 17  7  9  5]

# %% [markdown]
# **Final Cleaned Dataset**

# %%
print(df.shape)
print(df.head())
# Out:
# (588101, 6)
#    user id test group  converted  total ads most ads day  most ads hour
# 0  1069124         ad      False        130       Monday             20
# 1  1119715         ad      False         93      Tuesday             22
# 2  1144181         ad      False         21      Tuesday             18
# 3  1435133         ad      False        355      Tuesday             10
# 4  1015700         ad      False        276       Friday             14

# %%
df.to_csv('cleaned_marketing.csv', index=False)

# %% [markdown]
# **Cleaning Notes** <br>
# 1.The dataset contained no duplicate records. <br>
# 2.No missing values were present in any column.<br>
# 3.The redundant Unnamed: 0 (index) column was dropped from the cleaned dataset. <br>
# 4.Data types across all columns were verified and confirmed to be correct.<br>
# 5.The categorical columns (test group, most ads day) were reviewed and kept as is.<br>
# 6.The numeric columns (user id, total ads, most ads hour) were checked and validated.<br>
# 7.The boolean values in the converted column remained intact and unchanged.
